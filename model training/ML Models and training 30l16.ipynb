# %%
import pickle
import numpy as np
import cv2
from matplotlib import pyplot as plt
import math
#загрузка массива данных для обучения моделей
filename='data30'

imall,yy = pickle.load(open(filename, 'rb'))
# масштабирование величины яркости пикселей из формы 0-255 в форму 0 - 1
imall=imall/255.0
yy.shape
weight=(len(yy)-yy.sum())/yy.sum()

# %%
#отрисовка элемената b и вывод значения сфера или нет
b=4121
plt.imshow(np.reshape(imall[b,:],(32,32)))
yy[b]
# Out:
# 1.0

# %%
#разбивка массива анных на тестовую 5% и обучающую выборки 95%
from sklearn.model_selection import  train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(imall,yy,random_state=0,test_size=0.05)


#преобразование формы массива для ее соответствия функции fit керас
Xtrain=np.reshape(Xtrain,(len(Xtrain),32,32,1)).astype('float32')
ytrain=np.reshape(ytrain,(len(ytrain),1)).astype('float32')
Xtest=np.reshape(Xtest,(len(Xtest),32,32,1)).astype('float32')
ytest=np.reshape(ytest,(len(ytest),1)).astype('float32')

ytr1=np.zeros((len(ytrain),1))
ytr2=np.zeros((len(ytrain),1))
ytr1[ytrain==0]=1
ytr1[ytrain==1]=1
ytr=np.hstack((ytr1,ytr2))

yte1=np.zeros((len(ytest),1))
yte2=np.zeros((len(ytest),1))
yte1[ytest==0]=1
yte1[ytest==1]=1
yte=np.hstack((yte1,yte2))

# %%
#загрузка керас и тензорфлоу
import os
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf
import cv2
import os
import math
import random
import pickle
#keras import and windows InteractiveSession bug fix
from tensorflow.keras.optimizers import SGD,schedules
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
from tensorflow.keras.models import load_model
from tensorflow.keras import metrics as ms
from tensorflow.keras import  Model
from tensorflow.keras.layers import Input,Conv2D, Concatenate, MaxPooling2D,Activation,concatenate,AveragePooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import UpSampling2D, Dropout, BatchNormalization,Flatten,Dense,Reshape

import tensorflow.keras.backend as K


config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Concatenate, MaxPooling2D,Conv2DTranspose,Input
from tensorflow.keras.layers import UpSampling2D, Dropout, BatchNormalization

# %%
from tensorflow.keras.models import load_model
#обучение 7 разных моделей с кратно увеличивающимся количеством конволюционных слоев
dim=16
modelhs=[]
ps=32
for i in range(1): #7
    model = load_model('model3ll16.h5')
    '''
    print(dim)
    model = tf.keras.Sequential()
    
    model.add(Conv2D(dim, kernel_size=(3,3), padding='same', input_shape=(ps, ps, 1), activation='elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(dim, (3,3), padding='same', activation='elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(dim*2, (3,3), padding='same', activation='elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(dim*2, (3,3), padding='same', activation='elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.5))


    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='sigmoid'))

    
    
    model.add(Flatten(input_shape=(32, 32, 1)))
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(2, activation='relu'))
    model.add(BatchNormalization())  
        
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    opt = tf.keras.optimizers.SGD(lr=0.01, decay=0.025 / 200, momentum=0.9, nesterov=False)
    model.compile(optimizer=opt,
        loss='binary_crossentropy',
        metrics=['accuracy'])

    '''
    class_weights = {0: 1.,
                    1: weight}

    K.set_value(model.optimizer.learning_rate, 0.005)
    model.summary()
    # train the network
    H=model.fit(Xtrain, ytrain, epochs=200, validation_data=(Xtest, ytest),class_weight =class_weights, verbose=1,shuffle = True, batch_size=1000)
    model.save('model30x'+str(16)+'n.h5', overwrite=True)
    #формирование массива с историей обучения моделей
    modelhs.append(dim)
    modelhs.append(H.history['loss'])
    modelhs.append(H.history["val_loss"])
    modelhs.append(H.history["accuracy"])
    modelhs.append(H.history["val_accuracy"])
    dim=dim*2
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        160
#
#  batch_normalization_3 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 32)        4640
#
#  batch_normalization_4 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 32)          0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 64)          18496
#
#  batch_normalization_5 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 32)                32800
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 56,577
# Trainable params: 56,353
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/200
# 735/735 [==============================] - 33s 26ms/step - loss: 0.1750 - accuracy: 0.9731 - val_loss: 0.0403 - val_accuracy: 0.9870
# Epoch 2/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.1349 - accuracy: 0.9762 - val_loss: 0.0376 - val_accuracy: 0.9869
# Epoch 3/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1254 - accuracy: 0.9772 - val_loss: 0.0374 - val_accuracy: 0.9875
# Epoch 4/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1178 - accuracy: 0.9781 - val_loss: 0.0395 - val_accuracy: 0.9872
# Epoch 5/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1106 - accuracy: 0.9791 - val_loss: 0.0420 - val_accuracy: 0.9848
# Epoch 6/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1113 - accuracy: 0.9792 - val_loss: 0.0547 - val_accuracy: 0.9819
# Epoch 7/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1093 - accuracy: 0.9794 - val_loss: 0.0425 - val_accuracy: 0.9861
# Epoch 8/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1034 - accuracy: 0.9806 - val_loss: 0.0440 - val_accuracy: 0.9853
# Epoch 9/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1039 - accuracy: 0.9804 - val_loss: 0.0288 - val_accuracy: 0.9911
# Epoch 10/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1035 - accuracy: 0.9806 - val_loss: 0.0333 - val_accuracy: 0.9890
# Epoch 11/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.1002 - accuracy: 0.9812 - val_loss: 0.0301 - val_accuracy: 0.9900
# Epoch 12/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0985 - accuracy: 0.9814 - val_loss: 0.0299 - val_accuracy: 0.9901
# Epoch 13/200
# 735/735 [==============================] - 21s 28ms/step - loss: 0.0968 - accuracy: 0.9813 - val_loss: 0.0294 - val_accuracy: 0.9905
# Epoch 14/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0971 - accuracy: 0.9813 - val_loss: 0.0330 - val_accuracy: 0.9888
# Epoch 15/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0946 - accuracy: 0.9817 - val_loss: 0.0326 - val_accuracy: 0.9889
# Epoch 16/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0950 - accuracy: 0.9817 - val_loss: 0.0311 - val_accuracy: 0.9894
# Epoch 17/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0937 - accuracy: 0.9819 - val_loss: 0.0259 - val_accuracy: 0.9917
# Epoch 18/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0914 - accuracy: 0.9819 - val_loss: 0.0336 - val_accuracy: 0.9888
# Epoch 19/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0918 - accuracy: 0.9824 - val_loss: 0.0325 - val_accuracy: 0.9887
# Epoch 20/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0893 - accuracy: 0.9824 - val_loss: 0.0410 - val_accuracy: 0.9865
# Epoch 21/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0910 - accuracy: 0.9821 - val_loss: 0.0457 - val_accuracy: 0.9838
# Epoch 22/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0894 - accuracy: 0.9824 - val_loss: 0.0646 - val_accuracy: 0.9790
# Epoch 23/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0867 - accuracy: 0.9829 - val_loss: 0.0247 - val_accuracy: 0.9920
# Epoch 24/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0872 - accuracy: 0.9826 - val_loss: 0.0305 - val_accuracy: 0.9897
# Epoch 25/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0854 - accuracy: 0.9832 - val_loss: 0.0340 - val_accuracy: 0.9883
# Epoch 26/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0856 - accuracy: 0.9833 - val_loss: 0.0345 - val_accuracy: 0.9884
# Epoch 27/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0865 - accuracy: 0.9829 - val_loss: 0.0314 - val_accuracy: 0.9895
# Epoch 28/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0854 - accuracy: 0.9831 - val_loss: 0.0291 - val_accuracy: 0.9900
# Epoch 29/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0860 - accuracy: 0.9832 - val_loss: 0.0278 - val_accuracy: 0.9905
# Epoch 30/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0833 - accuracy: 0.9834 - val_loss: 0.0388 - val_accuracy: 0.9866
# Epoch 31/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0829 - accuracy: 0.9834 - val_loss: 0.0259 - val_accuracy: 0.9911
# Epoch 32/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0835 - accuracy: 0.9834 - val_loss: 0.0237 - val_accuracy: 0.9923
# Epoch 33/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0851 - accuracy: 0.9829 - val_loss: 0.0352 - val_accuracy: 0.9877
# Epoch 34/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0839 - accuracy: 0.9833 - val_loss: 0.0244 - val_accuracy: 0.9914
# Epoch 35/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0827 - accuracy: 0.9836 - val_loss: 0.0257 - val_accuracy: 0.9910
# Epoch 36/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0815 - accuracy: 0.9837 - val_loss: 0.0389 - val_accuracy: 0.9867
# Epoch 37/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0797 - accuracy: 0.9841 - val_loss: 0.0300 - val_accuracy: 0.9906
# Epoch 38/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0815 - accuracy: 0.9837 - val_loss: 0.0283 - val_accuracy: 0.9899
# Epoch 39/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0790 - accuracy: 0.9840 - val_loss: 0.0295 - val_accuracy: 0.9899
# Epoch 40/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0790 - accuracy: 0.9840 - val_loss: 0.0540 - val_accuracy: 0.9801
# Epoch 41/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0781 - accuracy: 0.9842 - val_loss: 0.0359 - val_accuracy: 0.9870
# Epoch 42/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0837 - accuracy: 0.9834 - val_loss: 0.0257 - val_accuracy: 0.9909
# Epoch 43/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0794 - accuracy: 0.9841 - val_loss: 0.0298 - val_accuracy: 0.9899
# Epoch 44/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0758 - accuracy: 0.9847 - val_loss: 0.0298 - val_accuracy: 0.9894
# Epoch 45/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0788 - accuracy: 0.9839 - val_loss: 0.0317 - val_accuracy: 0.9885
# Epoch 46/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0775 - accuracy: 0.9845 - val_loss: 0.0291 - val_accuracy: 0.9900
# Epoch 47/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0774 - accuracy: 0.9845 - val_loss: 0.0315 - val_accuracy: 0.9889
# Epoch 48/200
# 735/735 [==============================] - 20s 27ms/step - loss: 0.0766 - accuracy: 0.9845 - val_loss: 0.0426 - val_accuracy: 0.9857
# Epoch 49/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0772 - accuracy: 0.9843 - val_loss: 0.0325 - val_accuracy: 0.9888
# Epoch 50/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0763 - accuracy: 0.9844 - val_loss: 0.0220 - val_accuracy: 0.9927
# Epoch 51/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0752 - accuracy: 0.9848 - val_loss: 0.0335 - val_accuracy: 0.9884
# Epoch 52/200
# 735/735 [==============================] - 22s 29ms/step - loss: 0.0767 - accuracy: 0.9846 - val_loss: 0.0246 - val_accuracy: 0.9916
# Epoch 53/200
# 735/735 [==============================] - 22s 30ms/step - loss: 0.0740 - accuracy: 0.9852 - val_loss: 0.0240 - val_accuracy: 0.9921
# Epoch 54/200
# 735/735 [==============================] - 22s 30ms/step - loss: 0.0745 - accuracy: 0.9849 - val_loss: 0.0346 - val_accuracy: 0.9881
# Epoch 55/200
# 735/735 [==============================] - 24s 33ms/step - loss: 0.0754 - accuracy: 0.9847 - val_loss: 0.0264 - val_accuracy: 0.9910
# Epoch 56/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0748 - accuracy: 0.9848 - val_loss: 0.0335 - val_accuracy: 0.9885
# Epoch 57/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0729 - accuracy: 0.9850 - val_loss: 0.0320 - val_accuracy: 0.9887
# Epoch 58/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0750 - accuracy: 0.9846 - val_loss: 0.0319 - val_accuracy: 0.9887
# Epoch 59/200
# 735/735 [==============================] - 26s 35ms/step - loss: 0.0723 - accuracy: 0.9852 - val_loss: 0.0338 - val_accuracy: 0.9887
# Epoch 60/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0729 - accuracy: 0.9851 - val_loss: 0.0278 - val_accuracy: 0.9902
# Epoch 61/200
# 735/735 [==============================] - 26s 36ms/step - loss: 0.0729 - accuracy: 0.9852 - val_loss: 0.0235 - val_accuracy: 0.9914
# Epoch 62/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0723 - accuracy: 0.9851 - val_loss: 0.0226 - val_accuracy: 0.9922
# Epoch 63/200
# 735/735 [==============================] - 26s 35ms/step - loss: 0.0734 - accuracy: 0.9851 - val_loss: 0.0280 - val_accuracy: 0.9908
# Epoch 64/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0714 - accuracy: 0.9852 - val_loss: 0.0331 - val_accuracy: 0.9886
# Epoch 65/200
# 735/735 [==============================] - 26s 35ms/step - loss: 0.0710 - accuracy: 0.9852 - val_loss: 0.0438 - val_accuracy: 0.9848
# Epoch 66/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0724 - accuracy: 0.9853 - val_loss: 0.0286 - val_accuracy: 0.9895
# Epoch 67/200
# 735/735 [==============================] - 24s 33ms/step - loss: 0.0725 - accuracy: 0.9851 - val_loss: 0.0279 - val_accuracy: 0.9901
# Epoch 68/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0705 - accuracy: 0.9853 - val_loss: 0.0271 - val_accuracy: 0.9908
# Epoch 69/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0726 - accuracy: 0.9854 - val_loss: 0.0423 - val_accuracy: 0.9853
# Epoch 70/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0726 - accuracy: 0.9853 - val_loss: 0.0265 - val_accuracy: 0.9903
# Epoch 71/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0717 - accuracy: 0.9855 - val_loss: 0.0251 - val_accuracy: 0.9913
# Epoch 72/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0709 - accuracy: 0.9856 - val_loss: 0.0215 - val_accuracy: 0.9925
# Epoch 73/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0720 - accuracy: 0.9855 - val_loss: 0.0364 - val_accuracy: 0.9874
# Epoch 74/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0699 - accuracy: 0.9856 - val_loss: 0.0231 - val_accuracy: 0.9926
# Epoch 75/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0704 - accuracy: 0.9856 - val_loss: 0.0241 - val_accuracy: 0.9914
# Epoch 76/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0699 - accuracy: 0.9856 - val_loss: 0.0344 - val_accuracy: 0.9876
# Epoch 77/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0706 - accuracy: 0.9855 - val_loss: 0.0222 - val_accuracy: 0.9921
# Epoch 78/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0693 - accuracy: 0.9860 - val_loss: 0.0233 - val_accuracy: 0.9919
# Epoch 79/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0690 - accuracy: 0.9858 - val_loss: 0.0262 - val_accuracy: 0.9907
# Epoch 80/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0705 - accuracy: 0.9852 - val_loss: 0.0241 - val_accuracy: 0.9916
# Epoch 81/200
# 735/735 [==============================] - 25s 34ms/step - loss: 0.0689 - accuracy: 0.9860 - val_loss: 0.0274 - val_accuracy: 0.9904
# Epoch 82/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0693 - accuracy: 0.9859 - val_loss: 0.0516 - val_accuracy: 0.9820
# Epoch 83/200
# 735/735 [==============================] - 28s 37ms/step - loss: 0.0683 - accuracy: 0.9860 - val_loss: 0.0367 - val_accuracy: 0.9869
# Epoch 84/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0685 - accuracy: 0.9858 - val_loss: 0.0242 - val_accuracy: 0.9920
# Epoch 85/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0691 - accuracy: 0.9857 - val_loss: 0.0386 - val_accuracy: 0.9868
# Epoch 86/200
# 735/735 [==============================] - 28s 37ms/step - loss: 0.0696 - accuracy: 0.9857 - val_loss: 0.0359 - val_accuracy: 0.9874
# Epoch 87/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0681 - accuracy: 0.9862 - val_loss: 0.0292 - val_accuracy: 0.9891
# Epoch 88/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0678 - accuracy: 0.9860 - val_loss: 0.0437 - val_accuracy: 0.9849
# Epoch 89/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0689 - accuracy: 0.9859 - val_loss: 0.0262 - val_accuracy: 0.9923
# Epoch 90/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0680 - accuracy: 0.9859 - val_loss: 0.0286 - val_accuracy: 0.9895
# Epoch 91/200
# 735/735 [==============================] - 24s 33ms/step - loss: 0.0683 - accuracy: 0.9860 - val_loss: 0.0284 - val_accuracy: 0.9899
# Epoch 92/200
# 735/735 [==============================] - 26s 36ms/step - loss: 0.0686 - accuracy: 0.9858 - val_loss: 0.0253 - val_accuracy: 0.9909
# Epoch 93/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0660 - accuracy: 0.9863 - val_loss: 0.0264 - val_accuracy: 0.9909
# Epoch 94/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0672 - accuracy: 0.9863 - val_loss: 0.0241 - val_accuracy: 0.9921
# Epoch 95/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0677 - accuracy: 0.9862 - val_loss: 0.0291 - val_accuracy: 0.9893
# Epoch 96/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0664 - accuracy: 0.9861 - val_loss: 0.0241 - val_accuracy: 0.9916
# Epoch 97/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0676 - accuracy: 0.9861 - val_loss: 0.0291 - val_accuracy: 0.9901
# Epoch 98/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0660 - accuracy: 0.9864 - val_loss: 0.0252 - val_accuracy: 0.9908
# Epoch 99/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0669 - accuracy: 0.9861 - val_loss: 0.0268 - val_accuracy: 0.9909
# Epoch 100/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0665 - accuracy: 0.9862 - val_loss: 0.0215 - val_accuracy: 0.9929
# Epoch 101/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0644 - accuracy: 0.9868 - val_loss: 0.0291 - val_accuracy: 0.9894
# Epoch 102/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0659 - accuracy: 0.9862 - val_loss: 0.0221 - val_accuracy: 0.9922
# Epoch 103/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0649 - accuracy: 0.9865 - val_loss: 0.0296 - val_accuracy: 0.9901
# Epoch 104/200
# 735/735 [==============================] - 26s 35ms/step - loss: 0.0655 - accuracy: 0.9865 - val_loss: 0.0263 - val_accuracy: 0.9913
# Epoch 105/200
# 735/735 [==============================] - 23s 31ms/step - loss: 0.0671 - accuracy: 0.9861 - val_loss: 0.0409 - val_accuracy: 0.9860
# Epoch 106/200
# 735/735 [==============================] - 22s 30ms/step - loss: 0.0638 - accuracy: 0.9871 - val_loss: 0.0341 - val_accuracy: 0.9875
# Epoch 107/200
# 735/735 [==============================] - 22s 30ms/step - loss: 0.0654 - accuracy: 0.9862 - val_loss: 0.0281 - val_accuracy: 0.9903
# Epoch 108/200
# 735/735 [==============================] - 23s 31ms/step - loss: 0.0651 - accuracy: 0.9865 - val_loss: 0.0530 - val_accuracy: 0.9811
# Epoch 109/200
# 735/735 [==============================] - 24s 32ms/step - loss: 0.0667 - accuracy: 0.9863 - val_loss: 0.0221 - val_accuracy: 0.9929
# Epoch 110/200
# 735/735 [==============================] - 28s 38ms/step - loss: 0.0647 - accuracy: 0.9865 - val_loss: 0.0230 - val_accuracy: 0.9924
# Epoch 111/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0651 - accuracy: 0.9865 - val_loss: 0.0293 - val_accuracy: 0.9895
# Epoch 112/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0657 - accuracy: 0.9865 - val_loss: 0.0254 - val_accuracy: 0.9910
# Epoch 113/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0651 - accuracy: 0.9866 - val_loss: 0.0211 - val_accuracy: 0.9930
# Epoch 114/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0642 - accuracy: 0.9869 - val_loss: 0.0223 - val_accuracy: 0.9922
# Epoch 115/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0657 - accuracy: 0.9864 - val_loss: 0.0304 - val_accuracy: 0.9894
# Epoch 116/200
# 735/735 [==============================] - 27s 36ms/step - loss: 0.0633 - accuracy: 0.9869 - val_loss: 0.0277 - val_accuracy: 0.9911
# Epoch 117/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0628 - accuracy: 0.9870 - val_loss: 0.0291 - val_accuracy: 0.9905
# Epoch 118/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0632 - accuracy: 0.9870 - val_loss: 0.0206 - val_accuracy: 0.9931
# Epoch 119/200
# 735/735 [==============================] - 27s 37ms/step - loss: 0.0620 - accuracy: 0.9871 - val_loss: 0.0252 - val_accuracy: 0.9909
# Epoch 120/200
# 735/735 [==============================] - 21s 28ms/step - loss: 0.0627 - accuracy: 0.9870 - val_loss: 0.0390 - val_accuracy: 0.9855
# Epoch 121/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0629 - accuracy: 0.9869 - val_loss: 0.0239 - val_accuracy: 0.9925
# Epoch 122/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0619 - accuracy: 0.9873 - val_loss: 0.0253 - val_accuracy: 0.9908
# Epoch 123/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0636 - accuracy: 0.9869 - val_loss: 0.0407 - val_accuracy: 0.9859
# Epoch 124/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.0627 - accuracy: 0.9871 - val_loss: 0.0226 - val_accuracy: 0.9932
# Epoch 125/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0622 - accuracy: 0.9871 - val_loss: 0.0244 - val_accuracy: 0.9916
# Epoch 126/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0621 - accuracy: 0.9872 - val_loss: 0.0234 - val_accuracy: 0.9919
# Epoch 127/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0646 - accuracy: 0.9868 - val_loss: 0.0284 - val_accuracy: 0.9920
# Epoch 128/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0631 - accuracy: 0.9871 - val_loss: 0.0247 - val_accuracy: 0.9924
# Epoch 129/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0627 - accuracy: 0.9871 - val_loss: 0.0206 - val_accuracy: 0.9925
# Epoch 130/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0632 - accuracy: 0.9869 - val_loss: 0.0213 - val_accuracy: 0.9923
# Epoch 131/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0636 - accuracy: 0.9870 - val_loss: 0.0547 - val_accuracy: 0.9895
# Epoch 132/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0604 - accuracy: 0.9877 - val_loss: 0.0189 - val_accuracy: 0.9937
# Epoch 133/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0620 - accuracy: 0.9871 - val_loss: 0.0228 - val_accuracy: 0.9931
# Epoch 134/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0625 - accuracy: 0.9872 - val_loss: 0.0276 - val_accuracy: 0.9911
# Epoch 135/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.0626 - accuracy: 0.9873 - val_loss: 0.0341 - val_accuracy: 0.9876
# Epoch 136/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0623 - accuracy: 0.9871 - val_loss: 0.0225 - val_accuracy: 0.9923
# Epoch 137/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0609 - accuracy: 0.9873 - val_loss: 0.0281 - val_accuracy: 0.9899
# Epoch 138/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0628 - accuracy: 0.9870 - val_loss: 0.0326 - val_accuracy: 0.9888
# Epoch 139/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0643 - accuracy: 0.9868 - val_loss: 0.0292 - val_accuracy: 0.9900
# Epoch 140/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0620 - accuracy: 0.9871 - val_loss: 0.0279 - val_accuracy: 0.9904
# Epoch 141/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0609 - accuracy: 0.9873 - val_loss: 0.0344 - val_accuracy: 0.9888
# Epoch 142/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0611 - accuracy: 0.9874 - val_loss: 0.0295 - val_accuracy: 0.9901
# Epoch 143/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.0618 - accuracy: 0.9873 - val_loss: 0.0271 - val_accuracy: 0.9910
# Epoch 144/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0617 - accuracy: 0.9874 - val_loss: 0.0203 - val_accuracy: 0.9930
# Epoch 145/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0616 - accuracy: 0.9872 - val_loss: 0.0187 - val_accuracy: 0.9940
# Epoch 146/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0604 - accuracy: 0.9874 - val_loss: 0.0212 - val_accuracy: 0.9928
# Epoch 147/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0597 - accuracy: 0.9876 - val_loss: 0.0377 - val_accuracy: 0.9871
# Epoch 148/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0589 - accuracy: 0.9875 - val_loss: 0.0407 - val_accuracy: 0.9858
# Epoch 149/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.0600 - accuracy: 0.9876 - val_loss: 0.0440 - val_accuracy: 0.9848
# Epoch 150/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0604 - accuracy: 0.9874 - val_loss: 0.0362 - val_accuracy: 0.9915
# Epoch 151/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0600 - accuracy: 0.9878 - val_loss: 0.0249 - val_accuracy: 0.9918
# Epoch 152/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0602 - accuracy: 0.9876 - val_loss: 0.0205 - val_accuracy: 0.9925
# Epoch 153/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0605 - accuracy: 0.9875 - val_loss: 0.0255 - val_accuracy: 0.9919
# Epoch 154/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0601 - accuracy: 0.9874 - val_loss: 0.0207 - val_accuracy: 0.9932
# Epoch 155/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0602 - accuracy: 0.9878 - val_loss: 0.0256 - val_accuracy: 0.9909
# Epoch 156/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0584 - accuracy: 0.9878 - val_loss: 0.0264 - val_accuracy: 0.9905
# Epoch 157/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0600 - accuracy: 0.9875 - val_loss: 0.0383 - val_accuracy: 0.9873
# Epoch 158/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0598 - accuracy: 0.9875 - val_loss: 0.0287 - val_accuracy: 0.9903
# Epoch 159/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0590 - accuracy: 0.9877 - val_loss: 0.0269 - val_accuracy: 0.9910
# Epoch 160/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0591 - accuracy: 0.9877 - val_loss: 0.0328 - val_accuracy: 0.9888
# Epoch 161/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0601 - accuracy: 0.9875 - val_loss: 0.0219 - val_accuracy: 0.9932
# Epoch 162/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0601 - accuracy: 0.9874 - val_loss: 0.0223 - val_accuracy: 0.9922
# Epoch 163/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0578 - accuracy: 0.9880 - val_loss: 0.0264 - val_accuracy: 0.9933
# Epoch 164/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0610 - accuracy: 0.9874 - val_loss: 0.0296 - val_accuracy: 0.9902
# Epoch 165/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0580 - accuracy: 0.9878 - val_loss: 0.0272 - val_accuracy: 0.9910
# Epoch 166/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0577 - accuracy: 0.9878 - val_loss: 0.0316 - val_accuracy: 0.9886
# Epoch 167/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0600 - accuracy: 0.9878 - val_loss: 0.0236 - val_accuracy: 0.9935
# Epoch 168/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0575 - accuracy: 0.9879 - val_loss: 0.0239 - val_accuracy: 0.9931
# Epoch 169/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0592 - accuracy: 0.9877 - val_loss: 0.0347 - val_accuracy: 0.9885
# Epoch 170/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0586 - accuracy: 0.9878 - val_loss: 0.0307 - val_accuracy: 0.9900
# Epoch 171/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0584 - accuracy: 0.9878 - val_loss: 0.0209 - val_accuracy: 0.9938
# Epoch 172/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0594 - accuracy: 0.9877 - val_loss: 0.0464 - val_accuracy: 0.9840
# Epoch 173/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0573 - accuracy: 0.9879 - val_loss: 0.0271 - val_accuracy: 0.9908
# Epoch 174/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0591 - accuracy: 0.9877 - val_loss: 0.0283 - val_accuracy: 0.9908
# Epoch 175/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0592 - accuracy: 0.9879 - val_loss: 0.0263 - val_accuracy: 0.9907
# Epoch 176/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.0583 - accuracy: 0.9877 - val_loss: 0.0197 - val_accuracy: 0.9937
# Epoch 177/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0585 - accuracy: 0.9879 - val_loss: 0.0209 - val_accuracy: 0.9928
# Epoch 178/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0577 - accuracy: 0.9878 - val_loss: 0.0292 - val_accuracy: 0.9927
# Epoch 179/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0579 - accuracy: 0.9882 - val_loss: 0.0260 - val_accuracy: 0.9929
# Epoch 180/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0593 - accuracy: 0.9877 - val_loss: 0.0241 - val_accuracy: 0.9919
# Epoch 181/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0577 - accuracy: 0.9879 - val_loss: 0.0325 - val_accuracy: 0.9890
# Epoch 182/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0581 - accuracy: 0.9878 - val_loss: 0.0446 - val_accuracy: 0.9850
# Epoch 183/200
# 735/735 [==============================] - 19s 26ms/step - loss: 0.0578 - accuracy: 0.9881 - val_loss: 0.0197 - val_accuracy: 0.9936
# Epoch 184/200
# 735/735 [==============================] - 19s 25ms/step - loss: 0.0588 - accuracy: 0.9878 - val_loss: 0.0297 - val_accuracy: 0.9921
# Epoch 185/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0574 - accuracy: 0.9879 - val_loss: 0.0299 - val_accuracy: 0.9926
# Epoch 186/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0567 - accuracy: 0.9883 - val_loss: 0.0229 - val_accuracy: 0.9923
# Epoch 187/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0579 - accuracy: 0.9879 - val_loss: 0.0194 - val_accuracy: 0.9933
# Epoch 188/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0567 - accuracy: 0.9882 - val_loss: 0.0333 - val_accuracy: 0.9889
# Epoch 189/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0565 - accuracy: 0.9882 - val_loss: 0.0243 - val_accuracy: 0.9917
# Epoch 190/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0563 - accuracy: 0.9882 - val_loss: 0.0358 - val_accuracy: 0.9882
# Epoch 191/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0576 - accuracy: 0.9882 - val_loss: 0.0318 - val_accuracy: 0.9888
# Epoch 192/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0574 - accuracy: 0.9881 - val_loss: 0.0217 - val_accuracy: 0.9926
# Epoch 193/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0574 - accuracy: 0.9879 - val_loss: 0.0364 - val_accuracy: 0.9878
# Epoch 194/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0561 - accuracy: 0.9883 - val_loss: 0.0256 - val_accuracy: 0.9932
# Epoch 195/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0578 - accuracy: 0.9881 - val_loss: 0.0227 - val_accuracy: 0.9930
# Epoch 196/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0558 - accuracy: 0.9884 - val_loss: 0.0259 - val_accuracy: 0.9913
# Epoch 197/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0565 - accuracy: 0.9882 - val_loss: 0.0193 - val_accuracy: 0.9935
# Epoch 198/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0563 - accuracy: 0.9882 - val_loss: 0.0228 - val_accuracy: 0.9924
# Epoch 199/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0565 - accuracy: 0.9883 - val_loss: 0.0437 - val_accuracy: 0.9849
# Epoch 200/200
# 735/735 [==============================] - 18s 25ms/step - loss: 0.0568 - accuracy: 0.9880 - val_loss: 0.0259 - val_accuracy: 0.9913

# %%
#сохранение результатов обучения
filename='modellearn_data'
pickle.dump(modelhs, open(filename, 'wb'))
